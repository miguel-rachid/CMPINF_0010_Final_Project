# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#       id                                      facility_name     num  \
# 0  10762  North Versailles VFD / South Wilmerding Social...     830
# 1  10781                                Hill Top Lodge #151  128-30
# 2  10693                                  The Suburban Room    3113
# 3  10707                                      Hyd A Way Bar     NaN
# 4  10711                             Bratstvo Lodge #6 SNPJ     540
#
#           street              city state      zip         municipal  \
# 0     Sylvan Ave  North Versailles    PA  15137.0  North Versailles
# 1     Ormsby Ave        Pittsburgh    PA  15210.0         Mt Oliver
# 2  W Liberty Ave        Pittsburgh    PA  15216.0           Dormont
# 3         Box 39            Morgan    PA  15064.0     South Fayette
# 4    3rd  Avenue       Bridgeville    PA  15017.0       Bridgeville
#
#    category_cd             description  ...  bus_st_date bus_cl_date  \
# 0          250    Social Club-Bar Only  ...   1969-01-01         NaN
# ...

# %%
df2 = df.drop(['num', 'category_cd', 'bus_st_date', 'bus_cl_date', 'seat_count', 'noroom',
               'sq_feet', 'status', 'placard_st', 'x', 'y'], axis = 1)

# %%
df2.shape
# Out:
# (28626, 11)

# %%
def drop_rows_by_value(df, column_name, values_to_drop):
    # iterate through rows in the specified column and drop matching rows
    for index, row in df.iterrows():
        if row[column_name] in values_to_drop:
            df.drop(index, inplace=True)

    # return the updated dataframe
    return df

# %%
column_name = 'city'  # specify the column name to iterate over
word_to_remove = 'Pittsburgh'  # specify the word to remove

for index, row in df2.iterrows():
    if row[column_name] != word_to_remove:
        df2 = df2.drop(index)

print(df2)
# Out:
#                  id                     facility_name              street  \
# 1             10781               Hill Top Lodge #151          Ormsby Ave
# 2             10693                 The Suburban Room       W Liberty Ave
# 6             10734  Holiday Park Volunteer Fire Dept    Abers Creek Road
# 11            10605                    McArdle Tavern      Bingham Street
# 12            10606        Arlington Vets Association       Arlington Ave
# ...             ...                               ...                 ...
# 28619  202304110003        FTK Party & Entertainment   859 Memory Ln, 201
# 28621  202304110001                      Rialto Pizza   Greenfield Avenue
# 28623  202304110006                     Condado Tacos     Saint Simon Way
# 28624  202304110002                 Linx Bar & Lounge       Carson Street
# 28625  202304110004                          Doughbar       Carson Street
#
#              city state      zip           municipal  \
# ...

# %%
df2 = drop_rows_by_value(df2, 'description', ['Chain Packaged Food Only', 'Retail/Convenience Store', 
                                            'Chain Retail/Convenience Store', 'Chain Restaurant without Liquor',
                                            'Personal Care Boarding Home/Fee Exempt', 'Church Kitchen'])

# %%
df2.head(25)
# Out:
#               id                                     facility_name  \
# 1          10781                               Hill Top Lodge #151
# 2          10693                                 The Suburban Room
# 6          10734                  Holiday Park Volunteer Fire Dept
# 11         10605                                    McArdle Tavern
# 12         10606                        Arlington Vets Association
# 13         10636                   Pittsburgh Golf Club Restaurant
# 14         10591                                      Young Tavern
# 15         10638                                 Poli's Restaurant
# 16         10557                                    Anthonys Pizza
# 17         10558                                    Acapulco Joe's
# 18         10560                                      Bill's Place
# 25         37153                                         Quick Six
# 26         37166                                  Penn Aiken Dairy
# ...

# %%
df2 = drop_rows_by_value(df2, 'description', ['School Full Service Kitchen', 'School Full Service Kitchen/Exempt', 
                                              'Traditional Boarding Home/Fee Exempt', 'Nursing Home/Personal Care Comb.',
                                              'Mobile – Tier I (Unopened Pre-packaged Food Only)',
                                              'Traditional Boarding Home'])

# %%
df2 = drop_rows_by_value(df2, 'description', ['Personal Care Boarding Home', 'Food Processor',
                                              'Child Food Service', 'Packaged Food Only',
                                              'Mobile - Tier II ( Prepared Foods)', 'Commissary', 'Warehouse'])

# %%
df2 = drop_rows_by_value(df2, 'description', ['Transient Retail Food Processor', 'Nursing Home', 
                                              'Chain Bakery', 'Rooming House with Guest food Service',
                                              'Transient Caterer', 'Supermarket', 'Food Banks/ Food Pantries', 
                                              'Banquet Hall', 'Adult Food Service', 'Bakery', 'Caterer',
                                              'Nursing Home/Personal Care Snack Bar'])

# %%
df2 = drop_rows_by_value(df2, 'description', ['Chain Supermarket', 'University Food Service', 
                                              'School Satellite kitchen', 'Hotels - Limited Menu Food Service', 
                                              'Seasonal/Farmers Market', 'School Satellite Kitchen/Exempt', 
                                              'Nursing Home/Fee Exempt', 'Rooming House/Fee Exempt', 
                                              'Child Food Service/Fee Exempt', 'Community Service Facility'])

# %%
df2 = drop_rows_by_value(df2, 'description', ['School Headstart', 'Hospital', 'Gov',
                                              'University (limited)', 'Hospital/Other Institution', 
                                              'Nursing Home/Personal Care Comb./Fee Exempt', 
                                              'University Food Service/Fee Exempt', 'Pool Snack Bar/No Liquor'])

# %%
df2.head(25)
# Out:
#               id                     facility_name                  street  \
# 1          10781               Hill Top Lodge #151              Ormsby Ave
# 2          10693                 The Suburban Room           W Liberty Ave
# 6          10734  Holiday Park Volunteer Fire Dept        Abers Creek Road
# 11         10605                    McArdle Tavern          Bingham Street
# 12         10606        Arlington Vets Association           Arlington Ave
# 13         10636   Pittsburgh Golf Club Restaurant  Northumberland  Street
# 14         10591                      Young Tavern             E Carson St
# 15         10638                 Poli's Restaurant              Murray Ave
# 16         10557                    Anthonys Pizza          Brownsville Rd
# 17         10558                    Acapulco Joe's          Brownsville Rd
# 18         10560                      Bill's Place          Brownsville Rd
# ...

# %%
def filter_dataframe(df, column_name, numbers_to_check):
    
    matching_df = pd.DataFrame(columns=df.columns)

    
    for index, row in df.iterrows():
        if row[column_name] in numbers_to_check:
            
            matching_df = matching_df.append(row)

   
    return matching_df

# %%
df_15222 = filter_dataframe(df2, 'zip', [15222.0])
# Out:
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# ...

# %%
df_15222.head(50)
# Out:
#                 id                            facility_name  \
# 44    199904160001                             Caffe Amante
# 158          36465                                 Donnie's
# 270   199904140004                        Scarpaci Brothers
# 313          32646                               La Gondola
# 326          32591                              Mama Gina's
# 403          10065          Gene's Last Chance In The Strip
# 404          10067                         Lippiellos Pizza
# 405          10074                The Original Oyster House
# 406          10101                              Post Tavern
# 434          56493                        The Federal Court
# 445          37040                         Big Z Hamburgers
# 489          32118          Hilton Hotel / Three Rivers Pub
# 490          32121                 Hilton Hotel / Promenade
# 573          33736                     British Bicycle Club
# 578          33710                               Costanzo's
# ...

# %%
df_15213 = filter_dataframe(df2, 'zip', [15213.0])
# Out:
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# ...

# %%
df_15213.head(50)
# Out:
#                 id                            facility_name  \
# 49           36891                           Upstage Lounge
# 53           36869                              Holiday Bar
# 152          33413                          Sciulli's Pizza
# 195          33287                          Napoli Pizzeria
# 207          36326                       Panther Hollow Inn
# 307          11631                            Sullys Tavern
# 355   199903250001                                 Baba D's
# 357   199903250003                          Pittsburgh Cafe
# 398          10142             St Lorenzo Mutual Bene Assoc
# 401          10140               The Twentieth Century Club
# 456   199902250001                     Michael's Brick Oven
# 495          32086                      The House Of Chiang
# 520          36964         Dave & Andy's Homemade Ice Cream
# 533   199903080003             CMU/CK Pretzel Works/UC #232
# 560          10377                      Sweet Georgia Brown
# ...

# %%
df_15203 = filter_dataframe(df2, 'zip', [15203.0])
# Out:
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# ...

# %%
df_15203.head(50)
# Out:
#                 id                            facility_name  \
# 11           10605                           McArdle Tavern
# 14           10591                             Young Tavern
# 37    199904210008                        The Pickle Barrel
# 62           10570                     Red & Irene's Tavern
# 63           10573                           McCanns Tavern
# 66           10583                       S 18th St Cafe Inc
# 325          32589                             Co Go's #798
# 341   199903310002                     Southside Characters
# 433   199903150003                    Inn-Termission Lounge
# 683          33138      American Serbian Club of Pittsburgh
# 773          32526                               Dee's Cafe
# 786          35887                         Polish Army Vets
# 797          11949                                    Freds
# 872   199905070003                              Rex Theater
# 1055  199906280001                           Cafe Valentino
# ...

# %%
df_15219 = filter_dataframe(df2, 'zip', [15219.0])
# Out:
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# ...

# %%
df_15219.head(50)
# Out:
#                 id                                      facility_name  \
# 113          36516                                    The Rivers Club
# 221          33242                                  Eddies Restaurant
# 273   199904140007                                            Up Jaxx
# 288   199904070004                                           Shorty's
# 342   199904010001                                   Slice's Pizzeria
# 387   199903100007                                 R & B Coffee House
# 399          10115                                     Davis Hideaway
# 400          10116                                         Reds Place
# 402          10112                    The Pittsburgh Assn Of The Deaf
# 407          10056                                 Allegheny HYP Club
# 601          36612                                        Souper Bowl
# 770          32518                               USX Executive Dining
# ...

# %%
df_15201 = filter_dataframe(df2, 'zip', [15201.0])
# Out:
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# <ipython-input-25-a543fb3c327b>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   matching_df = matching_df.append(row)
# ...

# %%
df_15201.head(50)
# Out:
#                 id                            facility_name           street  \
# 260          36028                             Conley's Bar    Butler Street
# 339   199904050002                           Kelly's Korner          45th St
# 436   199903050005                                Fan Heads        Butler St
# 460   199902260004                         The Second Shift           Butler
# 551          38851                     Sufak's Round Corner        Butler St
# 564          10342              VFW / W R McNulty Post #214          52nd St
# 598          36650                            OK Grocery Co    35th and Avrr
# 725          35966                                Ray's Bar        Butler St
# 747          32958                  Orpheus Singing Society        Butler St
# 848          32400                Loyal Order Of Moose #581          51st St
# 1044         39437                                 Monico's        Butler St
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df2['description'].hist(orientation = 'horizontal')
